# %% [markdown]
# <p Style="text-align: right"> 02/06/2023</p>

# %% [markdown]
# <h1 style="background-color:Tomato; text-align: center">Contenedores China </h1>

# %% [markdown]
# <p> Las apuestas por la recuperación de la economía global están en duda, con el sombrío panorama que presentan los puertos de Shanghái, Ningbo y Shenzhen que acumulan contenedores vacíos a la espera de carga que no tiene demanda desde occidente. Según información publicada en el South China Morning Post,  un índice de tarifas de fletes de 15 rutas marítimas ha marcado una caída de 18% este año, con lo que el desplome se eleva al 82% desde enero de 2022, según Shanghai Shipping Exchange </p>

# %% [markdown]
# <h4 Style= "color:#80b0ab"> Puertos con mayor tráfico a nivel mundial</h4>

# %% [markdown]
# <ul>
#     <li>Puerto de Shanghai, China.</li>
#     <li>Puerto de Singapur, Singapur.</li>
#     <li>Puerto de Ningbo-Zhoushan, China.</li>
#     <li>Puerto de Shenzhen, China.</li>
#     <li>Puerto de Guangzhou, China.</li>
#     <li>Puerto de Busan, Corea del Sur.</li>
#
# </ul>

# %% [markdown]
# <img src="contenedor.jpeg">

# %% [markdown]
# <p Style="text-align :right"> 16/06/2023 </p>

# %% [markdown]
# <h2 Style = "color:#e1473f"> 1. Carga y estadarización de los set de datos </h2>
#
# <ol>
#     <li>Importar librerias</li>
#     <li>Importar set de datos</li>
#     <li>Revisión de encabezados</li>
#     <li>Fast EDA - Revisión de estadistica general del set de datos </li>
#     <li>Unir los set de datos</li>
# </ol>
#
#
#
# <h4 Style = "color:#80b0ab"> 1.1 Importación de librerias </h4>

# %%
import pandas as pd #Esto para manejo del DataFrame
import numpy as np #Esto se usa para el manejo de las estructuras de datos
import matplotlib.pyplot as plt #Se usa para crear gráficos con los datos
#Siempre si se necesita agregar una libreria más seria en este espacio
import matplotlib as mpl #se usa para importar las gráficas

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 1.2 Importación de set de datos </h4>

# %%
#URL del ejercicio https://archive.ics.uci.edu/dataset/10/automobile


cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors", 
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]


df_1er_autos = pd.read_csv ("autos.csv", names=cols)
df_2do_autos = pd.read_csv ("Autos1.csv", names=cols)

# %%
df_1er_autos.shape  #observaciones (Filas) y variables (Columnas)
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(5) #Con "head" trae los primeros 5 registros, y con "Tail" los ultimos 5
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_1er_autos.describe()  #Count es la cant de celdas ingresadas comparado con el .shape
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %%
df_1er_autos.head(4)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
#
# [4 rows x 26 columns]

# %%
df_2do_autos.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engine-size       bore     stroke  compression  horsepower  \
# count    29.000000  29.000000  29.000000    29.000000   29.000000
# mean    128.000000   3.330690   3.402069    11.475862  102.413793
# std      23.653752   0.240088   0.108278     5.318610   29.382353
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 1.3 Revisión de encabezados </h4>
#
# <ul>
#     <li>Nombres de las columnas no deben tener espacios en blanco</li>
#     <li>Nombres de columnas no deben comenzar con números</li>
#     <li>No deben existir nombres repetidos</li>
#     <li>Recomendación primera palabra debe ser en minus</li>
# </ul>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
#rename lleva 3 argumentos {el cambio del nombre:nombrereal}, (2do argumento)AXIS En el axis se usa 1 para cambiar el nombre de las columnas y 0 para cambiar el nombre de las filas,(3er argumento) True si se quiere aplicar en el mismo DF
df_1er_autos.rename({"engines-size":"engineSize"}, axis =1, inplace=True)
df_1er_autos.rename({"Cylinders":"cylinders"},axis =1, inplace=True)
df_1er_autos.rename({"City":"city"},axis =1, inplace=True)
df_1er_autos.rename({"Higway":"higway"},axis =1, inplace=True)

# %%
df_2do_autos.rename({"engines-size":"engineSize"}, axis =1, inplace=True)
df_2do_autos.rename({"Cylinders":"cylinders"},axis =1, inplace=True)
df_2do_autos.rename({"City":"city"},axis =1, inplace=True)
df_2do_autos.rename({"Higway":"higway"},axis =1, inplace=True)

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 1. Unir los set de datos </h4>

# %%
tplDataFrame = [df_1er_autos , df_2do_autos]
dfAutos = pd.concat(tplDataFrame)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 28
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    226 non-null    int64
#  1   normalized   226 non-null    object
#  2   make         226 non-null    object
#  3   fuel         226 non-null    object
#  4   aspiration   226 non-null    object
#  5   doors        226 non-null    object
#  6   style        226 non-null    object
#  7   wheels       226 non-null    object
#  8   engine       226 non-null    object
#  9   base         226 non-null    float64
#  10  length       226 non-null    float64
#  11  width        226 non-null    float64
#  12  heingt       226 non-null    float64
#  13  curb         226 non-null    int64
#  14  engineType   226 non-null    object
#  15  cylinders    226 non-null    object
#  16  engine-size  226 non-null    int64
#  17  system       226 non-null    object
# ...

# %% [markdown]
# <p Style="text-align :right"> 30/6/2023 </p>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 Style = "color:#e1473f"> 2.Manejo de valores faltantes  </h2>
#
# <ol>
#     <li>Identificar como se visualizan los valores faltantes en  DF</li>
#     <li>Contar la cantidad de valores faltantes por variables(Columnas)</li>
#     <li>Imputación simple de valores númericos</li>
#     <li>Imputación simple de valores categoricos </li>
#     <li>Eliminar observaciones del DF</li>
# </ol>
#
#
#
# <h4 Style = "color:#80b0ab"> 2.1 Identificar como se visualizan los valores faltantes en  DF</h4>

# %%
dfAutos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0          ?  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 24  front  100.4  ...           97     idi  3.01     3.4        23.0
# 25  front  100.4  ...          109    mpfi  3.19     3.4         9.0
# 26  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak city higway  price
# 24         68  4500   33     38  13845
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 28
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    226 non-null    int64
#  1   normalized   226 non-null    object
#  2   make         226 non-null    object
#  3   fuel         226 non-null    object
#  4   aspiration   226 non-null    object
#  5   doors        226 non-null    object
#  6   style        226 non-null    object
#  7   wheels       226 non-null    object
#  8   engine       226 non-null    object
#  9   base         226 non-null    float64
#  10  length       226 non-null    float64
#  11  width        226 non-null    float64
#  12  heingt       226 non-null    float64
#  13  curb         226 non-null    int64
#  14  engineType   226 non-null    object
#  15  cylinders    226 non-null    object
#  16  engine-size  226 non-null    int64
#  17  system       226 non-null    object
# ...

# %%
dfAutos.replace("?",np.nan, inplace=True)   #el signo de pregunta es lo que buscamos, el np.nan utilizando numpy reemplaza el ? por el Nan, y el inplace es para poder ver el reemplazo en el DF
dfAutos.head()
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 2.2 Contar la cantidad de valores faltantes por variables(Columnas) </h4>

# %%
dfTemp = dfAutos.isnull()
dfTemp.head(10)
#Se creó un df temporal para contar si los datos nulos indique si es verdadero.
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False        True  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False        True  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# ...

# %%
for columna in dfTemp.columns.values.tolist():
    print (columna)
    print (dfTemp[columna].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# cylinders
# False    226
# Name: cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 2.3 Imputación simple de valores númericos </h4>
#
# <p > No siempre se van a imputar todos los datos ya que se debe validar en cada caso dependiendo el contexto del análisis esto se consulta con el experto del tema, a validar si es posible suplantar estos datos.</p>

# %%
promNormalizadas= dfAutos["normalized"].astype("float").mean(axis=0)
dfAutos["normalized"].replace(np.nan, promNormalizadas, inplace=True)
dfAutos.head(5)
#Esto lo que hizo fue reemplazar los datos faltantes con un promedio de los datos existentes, siempre con datos "float"
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
promBore= dfAutos["bore"].astype("float").mean(axis=0)
dfAutos["bore"].replace(np.nan, promBore, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
promStroke= dfAutos["stroke"].astype("float").mean(axis=0)
dfAutos["stroke"].replace(np.nan, promStroke, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
promHorsepower= dfAutos["horsepower"].astype("float").mean(axis=0)
dfAutos["horsepower"].replace(np.nan, promStroke, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
promPeak= dfAutos["peak"].astype("float").mean(axis=0)
dfAutos["peak"].replace(np.nan, promStroke, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 2.4 Imputación simple de valores Categoricos </h4>

# %% [markdown]
# <p> Cuando son imputaciones de caracteres o tipo object, se realiza diferentes se hace por el valor más frecuente</p>

# %%
dfAutos["doors"].value_counts().idxmax()
#dfAutos["doors"]: Accede a la columna "doors" del DataFrame dfAutos.
#value_counts(): Calcula el recuento de ocurrencias de cada valor único en la columna 
#.idxmax(): Identifica el valor que tiene la máxima frecuencia. Devuelve el valor único que aparece con mayor frecuencia
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace=True)
dfAutos.head()
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 2.5 Eliminación de filas con valores faltantes </h4>

# %%
dfAutos.dropna(subset =["price"], axis=0 , inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfTemp = dfAutos.isnull()
for columna in dfTemp.columns.values.tolist():
    print (columna)
    print (dfTemp[columna].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# cylinders
# False    222
# Name: cylinders, dtype: int64
#
# engine-size
# False    222
# Name: engine-size, dtype: int64
#
# system
# False    222
# ...

# %% [markdown]
# <p Style="text-align :right"> 14/07/2023 </p>

# %% [markdown]
# <h2 Style = "color:#e1473f"> 3.Estardarización de Datos  </h2>
#
# <ol>
#     <li>Verificar el dominio de cada una de las variables, si es necesario se ajusta</li>
#     <li>Convertir valores en función de una interpretación o contexto(Tropicalizar datos)</li>
#     <li>Normalizar valores(volver comparables valores que son asimetricos entre sí</li>
#     <li>Crear categorias o rangos (Binning) </li>
#
# </ol>
#
#
#
# <h4 Style = "color:#80b0ab"> 3.1 Verificar el dominio de cada una de las variables</h4>

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# city             int64
# higway           int64
# price           object
# dtype: object

# %%
dfAutos[["normalized","horsepower","peak","price"]] = dfAutos [["normalized","horsepower","peak","price"]].astype("int")
dfAutos[["bore","stroke"]] = dfAutos [["bore","stroke"]].astype("float")

# %%
dfAutos.dtypes
#cuando se habla de dominio es que estén los valores leídos correctamente
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak             int32
# city             int64
# higway           int64
# price            int32
# dtype: object

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 3.2 Estandarizar los datos </h4>

# %%
dfAutos["city L/100km(calc)"] = 235/dfAutos["city"]
dfAutos["highway L/100km(calc)"] = 235/dfAutos["higway"]
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak city  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    higway  price  city L/100km(calc)  highway L/100km(calc)
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 3.3 Volver variables comparables </h4>

# %%
dfTemp= dfAutos[["horsepower","peak"]]
dfTemp.head(3)
# Out:
#    horsepower  peak
# 0         111  5000
# 1         111  5000
# 2         154  5000

# %%
dfAutos["horsepower (Normalizada)"] = dfAutos ["horsepower"]/dfAutos["horsepower"].max()
dfAutos["peak (Normalizada)"] = dfAutos ["peak"]/dfAutos["peak"].max()
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  compression  horsepower  peak  city higway  price  \
# 0    rwd  front  88.6  ...          9.0         111  5000    21     27  13495
# 1    rwd  front  88.6  ...          9.0         111  5000    21     27  16500
# 2    rwd  front  94.5  ...          9.0         154  5000    19     26  16500
# 3    fwd  front  99.8  ...         10.0         102  5500    24     30  13950
# 4    4wd  front  99.4  ...          8.0         115  5500    18     22  17450
#
# ...

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 3.4 Crear categorias o rangos (Binning) </h4>
#
# <p> En semana 6 se encuentra un artículo de este tema</p>

# %%
dfTemp.head(10)
# Out:
#    horsepower  peak
# 0         111  5000
# 1         111  5000
# 2         154  5000
# 3         102  5500
# 4         115  5500
# 5         110  5500
# 6         110  5500
# 7         110  5500
# 8         140  5500
# 9         101  5800

# %%
bins = np.linspace(48, 288, 4)
bins
# Out:
# array([ 48., 128., 208., 288.])

# %%
categoria =["bajo", "medio","alto"]
dfAutos["horsepower (bins)"] = pd.cut(dfAutos["horsepower"],bins,labels = categoria, include_lowest=True)
dfAutos[["horsepower", "horsepower (bins)"]].head(10)
# Out:
#    horsepower horsepower (bins)
# 0         111              bajo
# 1         111              bajo
# 2         154             medio
# 3         102              bajo
# 4         115              bajo
# 5         110              bajo
# 6         110              bajo
# 7         110              bajo
# 8         140             medio
# 9         101              bajo

# %% [markdown]
# <p Style="text-align :right"> 28/07/2023 </p>

# %% [markdown]
# <h2 style="color: #6495ED">6. Visualización de Datos</h2>
#
#
#
# <p>En este apartado se van a crear diferentes visualizaciones (Gráficas), las cuales nos ayudan a realizar la interpretaion y analisis de la informacion del set</p>
# </br>
#
#
#
# <p>Estos son tres elementos fundamentales para poder crear las visualizaciones:</p>
# <ol>
# <li>Preguntas de negocio a responder</li>
# <li>Pleno conocimiento del set de datos</li>
# <li>Experiencia de negocio</li>
# </ol>

# %% [markdown]
# <h5 style="color: #005f82">5.1 Configuración para los Gráficos</h5>
#
#
#
# <p>Cuantos Autos existen segun fabricante?
#    Cual fabricante tiene mayor presencia en el parque de Autos? </p>

# %% [markdown]
# <h4 Style = "color:#80b0ab"> 4.1 Configuración para los gráficos </h4>

# %%
#Remueve las lineas de los axis.
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
gf = dfAutos.groupby(['make']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                symboling
# make
# toyota                46
# volkswagen            24
# nissan                18
# mazda                 17
# mitsubishi            13
# honda                 13
# subaru                12
# peugot                11
# dodge                  9
# bmw                    8
# mercedes-benz          8
# plymouth               7
# saab                   6
# volvo                  6
# audi                   6
# porsche                4
# jaguar                 3
# chevrolet              3
# alfa-romero            3
# renault                2
# isuzu                  2
# mercury                1

# %%
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)

 

eje_x = gf.index.tolist()
data = gf["symboling"].tolist()

 

bar_colors = ['#69d2e7','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#fa6900']

 

ax.barh(eje_x, data, color=bar_colors)

 

#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO

 

title = "Grafico 1: Vehiculos en Inventario"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             )

 

#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun fabricante, en Costa Rica, periodo 2023"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

 

 

#FORMATO AL EJE (X/Y)
etiqueta = "cantidad de carros (ABS)"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

 

ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)

 

#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)

 

#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.80)

 

plt.show()

# %% [markdown]
# <h4 Style = "color:#80b0ab"> Cuantos autos existen en inventario segun la cantidad de caballos de fuerza? </h4>

# %%
hp = dfAutos.groupby(['horsepower']).count()
hp = hp.iloc[:,:1]
hp = hp.sort_values('horsepower', ascending=False)
hp
# Out:
#             symboling
# horsepower
# 262                 1
# 207                 3
# 200                 1
# 184                 2
# 182                 3
# 176                 2
# 175                 1
# 161                 4
# 160                 4
# 156                 4
# 155                 2
# 154                 1
# 152                 3
# 145                 5
# 143                 1
# 142                 1
# 140                 1
# 135                 1
# 123                 4
# 121                 3
# 120                 1
# 116                14
# 115                 1
# 114                 6
# 112                 2
# 111                 4
# 110                 9
# 102                 5
# 101                 6
# 100                 3
# 97                  5
# 95                  7
# 94                  2
# 92                  8
# 90                  5
# 88                  7
# 86                  4
# 85                  6
# 84                  5
# 82                  5
# ...

# %%
fig, ax = plt.subplots(1,1, figsize =(12,8), dpi=100)

 

eje_x1 = hp["symboling"].tolist()
data1 = hp.index.tolist()

 

bar_colors = ['#4f2621','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#7d7769','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
              '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
              '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#945396','#e5e5e5','#e5e5e5','#e5e5e5',
              '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#4f2621']

 

ax.bar( data1,eje_x1,width= 2, color=bar_colors)

 

#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO

 

title = "Gráfico 2: Cantidad de autos por Caballos de fuerza"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.10,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             )

 

#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados sus caballos de fuerza, en Costa Rica, periodo 2023"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.10,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

 

 

#FORMATO AL EJE (X/Y)
etiqueta = "cantidad de caballos de fuerza"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
etiquetay="Cantidad de carros"
ax.set_ylabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

 

ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
ax.yaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
 

#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 9)

 

#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.80)

 

plt.show()

# %% [markdown]
# <p Style="text-align :right"> 4/08/2023 </p>

# %%
gf = dfAutos.groupby(['horsepower']).count()

gf = gf.iloc[:,:1]

gf = gf.sort_values('symboling', ascending=False)

gf



fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)

 

eje_x = gf.index.tolist()

data = gf["symboling"].tolist()

 

bar_colors = ['#69d2e7']

 

ax.bar(eje_x, data, color=bar_colors)

 

#--------------------------------------------------------------------------------------------#

#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#

#--------------------------------------------------------------------------------------------#

#FORMATO DEL TITULO

 

title = "Grafico 2: Vehiculos en Inventario"

plt.suptitle(title,

             horizontalalignment = 'left',

             x = 0.001,

             y = 0.87,

             transform = fig.transFigure,

             fontsize = 20,

             fontweight = "bold",

             fontfamily = "serif",

             fontname = "Liberation Sans Narrow")

 

#FORMATO DEL SUBTITULO

subTitle = "Cantidad de vehiculos agrupados segun caballos de fuerza, en Costa Rica, periodo 2023"

ax.set_title(subTitle,

             horizontalalignment = "left",

             x = 0.001,

             y = 0.80,

             transform = fig.transFigure,

             fontsize = 15,

             fontweight = "regular",

             fontfamily = "serif")

 

 

#FORMATO AL EJE (X/Y)

etiqueta = "cantidad de caballos de fuerza (ABS)"

ax.set_xlabel(etiqueta,

              ha = 'left',

              fontsize = 10,

              fontweight = "regular",

              fontfamily = "serif")

 

etiquetay = "cantidad de carros"

ax.set_ylabel(etiquetay,

              ha = 'left',

              fontsize = 10,

              fontweight = "regular",

              fontfamily = "serif")

 

ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)

ax.yaxis.set_label_coords(x=-0.04, y=0.65, transform = ax.transAxes)

 

#FORMATO TAMANO LETRA AMBOS EJES

ax.tick_params(axis='both', labelsize = 10)

 

#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO

plt.subplots_adjust(top = 0.80)

 

plt.show()
# Out:
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.

# %%
gf = dfAutos.groupby(['horsepower (bins)']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                    symboling
# horsepower (bins)
# bajo                     180
# medio                     39
# alto                       1

# %%
fig, ax = plt.subplots(1,1, figsize =(11,6.9), dpi=100)

 

eje_x = gf.index.tolist()
data = gf["symboling"].tolist()

 

n = 222
x = dfAutos['engine-size']
y = dfAutos['city L/100km(calc)']
ax.scatter(x, y, c='#8dccad', alpha=0.3)

 

ax.grid(True)

 

 

#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO

 

title = "Grafico 6: Vehiculos en Inventario"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Liberation Sans Narrow")

 

#FORMATO DEL SUBTITULO
subTitle = "Relacion entre el tamano del motor y el consumo de gasolina"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

 

 

#FORMATO AL EJE (X/Y)
etiqueta = "Tamano del motor"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

 

etiquetay = "Consumo de gasolina en L/100km"
ax.set_ylabel(etiquetay,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

 

ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
ax.yaxis.set_label_coords(x=-0.04, y=0.45, transform = ax.transAxes)

 

#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)

 

#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.75)

 

plt.show()
# Out:
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.
# findfont: Font family 'Liberation Sans Narrow' not found.

# %%
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[50., 32.], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

ax.pie(vals.sum(axis=1), radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Pie plot with `ax.pie`')
plt.show()
